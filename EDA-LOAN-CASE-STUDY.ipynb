# %%
# Import all relevant Library
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# **Load CSV data on Panda Dataframe**
#
# ---

# %%
# Loading lean.csv in panda dataframe
df_orig_loan = pd.read_csv('/content/drive/MyDrive/Data-For-Analysis/loan.csv')
df_orig_loan.head()
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501    1296599       5000         5000           4975.0   36 months
# 1  1077430    1314167       2500         2500           2500.0   60 months
# 2  1077175    1313524       2400         2400           2400.0   36 months
# 3  1076863    1277178      10000        10000          10000.0   36 months
# 4  1075358    1311748       3000         3000           3000.0   60 months
#
#   int_rate  installment grade sub_grade                 emp_title emp_length  \
# 0   10.65%       162.87     B        B2                       NaN  10+ years
# 1   15.27%        59.83     C        C4                     Ryder   < 1 year
# 2   15.96%        84.33     C        C5                       NaN  10+ years
# 3   13.49%       339.31     C        C1       AIR RESOURCES BOARD  10+ years
# 4   12.69%        67.79     B        B5  University Medical Group     1 year
#
# ...

# %%
# Analysis of Dataframe
print("Dimension of df",df_orig_loan.shape)
print("\n")
print("**Column Info********************************************************")
info_loan=df_orig_loan.info(verbose=True)
print("Dataframe column details", "\n",info_loan)
# Out:
# Dimension of df (39717, 111)
#
#
# **Column Info********************************************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39717 entries, 0 to 39716
# Data columns (total 111 columns):
#  #    Column                          Dtype
# ---   ------                          -----
#  0    id                              int64
#  1    member_id                       int64
#  2    loan_amnt                       int64
#  3    funded_amnt                     int64
#  4    funded_amnt_inv                 float64
#  5    term                            object
#  6    int_rate                        object
#  7    installment                     float64
#  8    grade                           object
#  9    sub_grade                       object
#  10   emp_title                       object
#  11   emp_length                      object
#  12   home_ownership                  object
#  13   annual_inc                      float64
# ...

# %% [markdown]
# Get Details of Dataframe
#
# ---

# %%
# Increasing the row count of display
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 50)

# Analysis of Data frameColumn with null count
null_col_count=df_orig_loan.isnull().sum()
print(null_col_count.shape)
print("Dataframe column having null values", "\n",null_col_count[null_col_count>0])
print("********************************************************************")
print("Count of column having all Null rows ", null_col_count[null_col_count == df_orig_loan.shape[0]].count())
# Out:
# (111,)
# Dataframe column having null values
#  emp_title                          2459
# emp_length                         1075
# desc                              12942
# title                                11
# mths_since_last_delinq            25682
# mths_since_last_record            36931
# revol_util                           50
# last_pymnt_d                         71
# next_pymnt_d                      38577
# last_credit_pull_d                    2
# collections_12_mths_ex_med           56
# mths_since_last_major_derog       39717
# annual_inc_joint                  39717
# dti_joint                         39717
# verification_status_joint         39717
# tot_coll_amt                      39717
# tot_cur_bal                       39717
# open_acc_6m                       39717
# open_il_6m                        39717
# open_il_12m                       39717
# open_il_24m                       39717
# mths_since_rcnt_il                39717
# ...

# %%
# Cleaning the dataframe Dropping the columns having all null values
df_no_col_NA_loan=df_orig_loan.drop(null_col_count[null_col_count == df_orig_loan.shape[0]].index, axis=1)
null_col_count_after=df_no_col_NA_loan.isnull().sum()

print("Dataframe column having null values", "\n",null_col_count_after[null_col_count_after>0])
# Out:
# Dataframe column having null values
#  emp_title                      2459
# emp_length                     1075
# desc                          12942
# title                            11
# mths_since_last_delinq        25682
# mths_since_last_record        36931
# revol_util                       50
# last_pymnt_d                     71
# next_pymnt_d                  38577
# last_credit_pull_d                2
# collections_12_mths_ex_med       56
# chargeoff_within_12_mths         56
# pub_rec_bankruptcies            697
# tax_liens                        39
# dtype: int64

# %%
# Dropping the columns having majority of null values
#mths_since_last_delinq [25682],mths_since_last_record[36931] and next_pymnt_d[38577]
df_no_col_NA_loan=df_no_col_NA_loan.drop(['mths_since_last_delinq','mths_since_last_record','next_pymnt_d'], axis=1)

df_no_col_NA_loan.shape

null_col_count_after=df_no_col_NA_loan.isnull().sum()

print("Dataframe column having null values", "\n",null_col_count_after[null_col_count_after>0])
# Out:
# Dataframe column having null values
#  emp_title                      2459
# emp_length                     1075
# desc                          12942
# title                            11
# revol_util                       50
# last_pymnt_d                     71
# last_credit_pull_d                2
# collections_12_mths_ex_med       56
# chargeoff_within_12_mths         56
# pub_rec_bankruptcies            697
# tax_liens                        39
# dtype: int64

# %%
# Dimension of dataframe
print("Dimension of dataframe",df_no_col_NA_loan.shape)
# Columns not needes for analysis are emp_title, desc
df_no_col_NA_loan=df_no_col_NA_loan.drop(['emp_title','desc'], axis=1)

null_col_count_after=df_no_col_NA_loan.isnull().sum()

print("Dataframe column having null values", "\n",null_col_count_after[null_col_count_after>0])
print("Dimension of dataframe",df_no_col_NA_loan.shape)
# Out:
# Dimension of dataframe (39717, 54)
# Dataframe column having null values
#  emp_length                    1075
# title                           11
# revol_util                      50
# last_pymnt_d                    71
# last_credit_pull_d               2
# collections_12_mths_ex_med      56
# chargeoff_within_12_mths        56
# pub_rec_bankruptcies           697
# tax_liens                       39
# dtype: int64
# Dimension of dataframe (39717, 52)

# %%
# Cleaning of dataframe

# pub_rec_bankruptcies [Number of public record bankruptcies], changing NA to 0
df_no_col_NA_loan['pub_rec_bankruptcies'].fillna(0, inplace=True)

#Drop pymnt_plan as it has only one value
df_no_col_NA_loan=df_no_col_NA_loan.drop(['pymnt_plan'], axis=1)

# Drop url column as not needed for analysis
df_no_col_NA_loan=df_no_col_NA_loan.drop(['url'], axis=1)

# Drop desc col as not needed for analysis
#df_no_col_NA_loan=df_no_col_NA_loan.drop(['desc'], axis=1)

# Drop title col as not needed for analysis
df_no_col_NA_loan=df_no_col_NA_loan.drop(['title'], axis=1)

#Drop initial_list_status as it has only one value
df_no_col_NA_loan=df_no_col_NA_loan.drop(['initial_list_status'], axis=1)

# Drop aaplication_type as it has only one value individual
df_no_col_NA_loan=df_no_col_NA_loan.drop(['application_type'], axis=1)

# Dropping policy_code,collections_12_mths_ex_med,acc_now_delinq,chargeoff_within_12_mths,delinq_amnt and tax_liens as has only one value
df_no_col_NA_loan=df_no_col_NA_loan.drop(['policy_code','collections_12_mths_ex_med','acc_now_delinq','chargeoff_within_12_mths','delinq_amnt','tax_liens'], axis=1)

null_col_count_after=df_no_col_NA_loan.isnull().sum()

print("Dataframe column having null values", "\n",null_col_count_after[null_col_count_after>0])
# Out:
# Dataframe column having null values
#  emp_length            1075
# revol_util              50
# last_pymnt_d            71
# last_credit_pull_d       2
# dtype: int64

# %%
# Dimension of dataframe
print("Dimension of dataframe",df_no_col_NA_loan.shape)

print("**Column Info********************************************************")
info_loan=df_no_col_NA_loan.info(verbose=True)
print("Dataframe column details", "\n",info_loan)

object_columns = df_no_col_NA_loan.select_dtypes(include='object').columns
print("*********************************************************************","\n")
print("Object data tupe columns ",object_columns)
print("Object data tupe columns count",len(object_columns))
# Out:
# Dimension of dataframe (39717, 41)
# **Column Info********************************************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39717 entries, 0 to 39716
# Data columns (total 41 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       39717 non-null  int64
#  1   member_id                39717 non-null  int64
#  2   loan_amnt                39717 non-null  int64
#  3   funded_amnt              39717 non-null  int64
#  4   funded_amnt_inv          39717 non-null  float64
#  5   term                     39717 non-null  object
#  6   int_rate                 39717 non-null  object
#  7   installment              39717 non-null  float64
#  8   grade                    39717 non-null  object
#  9   sub_grade                39717 non-null  object
#  10  emp_length               38642 non-null  object
#  11  home_ownership           39717 non-null  object
# ...

# %%
# Cleaning dataframe Correcting column variable type
# term converting to int after removing months
df_no_col_NA_loan['term_in_month']= df_no_col_NA_loan['term'].str.replace(' months','')
df_no_col_NA_loan['term_in_month']= df_no_col_NA_loan['term_in_month'].astype(int)
df_no_col_NA_loan.drop(['term'], axis=1, inplace=True)

# int_rate column converting to percentage
df_no_col_NA_loan['int_rate_percent']= df_no_col_NA_loan['int_rate'].str.replace('%','')
df_no_col_NA_loan['int_rate_percent']= df_no_col_NA_loan['int_rate_percent'].astype(float)
df_no_col_NA_loan.drop(['int_rate'], axis=1, inplace=True)


# Converting issue_d as date in mmm-yy format
df_no_col_NA_loan['issue_d']= pd.to_datetime(df_no_col_NA_loan['issue_d'], format='%b-%y')

# Converting earliest_cr_line as date in mmm-yy format
df_no_col_NA_loan['earliest_cr_line']= pd.to_datetime(df_no_col_NA_loan['earliest_cr_line'], format='%b-%y')

# revol_util column converting to percentage
df_no_col_NA_loan['revol_util_percent']= df_no_col_NA_loan['revol_util'].str.replace('%','')
df_no_col_NA_loan['revol_util_percent']= df_no_col_NA_loan['revol_util_percent'].astype(float)
df_no_col_NA_loan.drop(['revol_util'], axis=1, inplace=True)

# Converting last_pymnt_d as date in mmm-yy format
df_no_col_NA_loan['last_pymnt_d']= pd.to_datetime(df_no_col_NA_loan['last_pymnt_d'], format='%b-%y')

# Converting last_credit_pull_d as date in mmm-yy format
df_no_col_NA_loan['last_credit_pull_d']= pd.to_datetime(df_no_col_NA_loan['last_credit_pull_d'], format='%b-%y')

# %%
# Dimension of dataframe
print("Dimension of dataframe",df_no_col_NA_loan.shape)

print("Dataframe column having null values", "\n",null_col_count_after[null_col_count_after>0])

print("**Column Info********************************************************")
info_loan=df_no_col_NA_loan.info(verbose=True)
print("Dataframe column details", "\n",info_loan)

object_columns = df_no_col_NA_loan.select_dtypes(include='object').columns
print("*********************************************************************","\n")
print("Object data tupe columns ",object_columns)
print("Object data tupe columns count",len(object_columns))

#Creating Final DataFrame
df_final_loan=df_no_col_NA_loan.copy()
# Out:
# Dimension of dataframe (39717, 41)
# Dataframe column having null values
#  emp_length            1075
# revol_util              50
# last_pymnt_d            71
# last_credit_pull_d       2
# dtype: int64
# **Column Info********************************************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39717 entries, 0 to 39716
# Data columns (total 41 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       39717 non-null  int64
#  1   member_id                39717 non-null  int64
#  2   loan_amnt                39717 non-null  int64
#  3   funded_amnt              39717 non-null  int64
#  4   funded_amnt_inv          39717 non-null  float64
#  5   installment              39717 non-null  float64
#  6   grade                    39717 non-null  object
#  7   sub_grade                39717 non-null  object
#  8   emp_length               38642 non-null  object
# ...

# %%
# Get details of columns
df_final_loan.describe(include = ['int', 'float'])
# Out:
#                  id     member_id     loan_amnt   funded_amnt  \
# count  3.971700e+04  3.971700e+04  39717.000000  39717.000000
# mean   6.831319e+05  8.504636e+05  11219.443815  10947.713196
# std    2.106941e+05  2.656783e+05   7456.670694   7187.238670
# min    5.473400e+04  7.069900e+04    500.000000    500.000000
# 25%    5.162210e+05  6.667800e+05   5500.000000   5400.000000
# 50%    6.656650e+05  8.508120e+05  10000.000000   9600.000000
# 75%    8.377550e+05  1.047339e+06  15000.000000  15000.000000
# max    1.077501e+06  1.314167e+06  35000.000000  35000.000000
#
#        funded_amnt_inv   installment    annual_inc           dti  \
# count     39717.000000  39717.000000  3.971700e+04  39717.000000
# mean      10397.448868    324.561922  6.896893e+04     13.315130
# std        7128.450439    208.874874  6.379377e+04      6.678594
# min           0.000000     15.690000  4.000000e+03      0.000000
# 25%        5000.000000    167.020000  4.040400e+04      8.170000
# ...

# %%
# Function to create new columns for loan amount bins

def add_loan_amt_bins(df):
  # Create a new column to store the bin assignments
  df['loan_amnt_bins'] = 'Other'
  for index, row in df.iterrows():
      if row['loan_amnt'] <= 7000:
          df.at[index, 'loan_amnt_bins'] = '0-7000'
      elif row['loan_amnt'] <= 14000:
          df.at[index, 'loan_amnt_bins'] = '7001-14000'
      elif row['loan_amnt'] <= 21000:
          df.at[index, 'loan_amnt_bins'] = '14001-21000'
      elif row['loan_amnt'] <= 28000:
          df.at[index, 'loan_amnt_bins'] = '21001-28000'
      elif row['loan_amnt'] <= 35000:
          df.at[index, 'loan_amnt_bins'] = '28001-35000'
      else:
          df.at[index, 'loan_amnt_bins'] = 'other'

# %%
# Remove ID and Member ID
df_final_loan_1 =df_final_loan.drop(['id','member_id'], axis=1)
# Split Data frame based on Loan Status
df_final_loan_1_Charged_off =df_final_loan_1[df_final_loan_1['loan_status']=='Charged Off']
add_loan_amt_bins(df_final_loan_1_Charged_off)
df_final_loan_1_Fully_Paid =df_final_loan_1[df_final_loan_1['loan_status']=='Fully Paid']
add_loan_amt_bins(df_final_loan_1_Fully_Paid)
df_final_loan_1_Current =df_final_loan_1[df_final_loan_1['loan_status']=='Current']
add_loan_amt_bins(df_final_loan_1_Current)

# %%
#Univariate Analysis
# Check the relation with Validation status, Home Ownership and grade

fig_1, ax_1 = plt.subplots (ncols=3, nrows=7, figsize=(15,30), sharex= True ,sharey=True)

# Calculate the sum of 'funded_amnt' for each 'verification_status'
fully_paid_sum = df_final_loan_1_Fully_Paid['funded_amnt'].groupby(df_final_loan_1_Fully_Paid['verification_status']).sum()
current_sum= df_final_loan_1_Current['funded_amnt'].groupby(df_final_loan_1_Current['verification_status']).sum()
charge_off_sum = df_final_loan_1_Charged_off['funded_amnt'].groupby(df_final_loan_1_Charged_off['verification_status']).sum()


# Draw pie chart on % distribution of validation status
#Use the index of the grouped data for x-axis values
fully_paid = ax_1[0][0].pie(fully_paid_sum.values, labels=fully_paid_sum.index,autopct='%1.1f%%',startangle=90)
current = ax_1[0][1].pie(current_sum.values, labels=current_sum.index,autopct='%1.1f%%',startangle=90)
charge_off = ax_1[0][2].pie(charge_off_sum.values, labels=charge_off_sum.index,autopct='%1.1f%%',startangle=90)


#Set Title
ax_1[0][0].title.set_text('Fully_Paid_Valid_stat')
ax_1[0][1].title.set_text('Current_Valid_stat')
ax_1[0][2].title.set_text('Charged_Off_Valid_stat')


# Check the relation with Home Ownership

# Calculate the sum of 'funded_amnt' for each 'house ownership'
fully_paid_sum = df_final_loan_1_Fully_Paid['funded_amnt'].groupby(df_final_loan_1_Fully_Paid['home_ownership']).sum()
current_sum= df_final_loan_1_Current['funded_amnt'].groupby(df_final_loan_1_Current['home_ownership']).sum()
charge_off_sum = df_final_loan_1_Charged_off['funded_amnt'].groupby(df_final_loan_1_Charged_off['home_ownership']).sum()



# Draw pie chart on % distribution of house ownership
#Use the index of the grouped data for x-axis values
fully_paid = ax_1[1][0].pie(fully_paid_sum.values, labels=fully_paid_sum.index,autopct='%1.1f%%',startangle=90)
current = ax_1[1][1].pie(current_sum.values, labels=current_sum.index,autopct='%1.1f%%',startangle=90)
charge_off = ax_1[1][2].pie(charge_off_sum.values, labels=charge_off_sum.index,autopct='%1.1f%%',startangle=90)


#Set Title
ax_1[1][0].title.set_text('Fully_Paid_Home_Ownership')
ax_1[1][1].title.set_text('Current_Home_Ownership')
ax_1[1][2].title.set_text('Charged_Off_Home_Ownership')

# Check the relation with grade

# Calculate the sum of 'funded_amnt' for each 'house ownership'
fully_paid_sum = df_final_loan_1_Fully_Paid['funded_amnt'].groupby(df_final_loan_1_Fully_Paid['grade']).sum()
current_sum= df_final_loan_1_Current['funded_amnt'].groupby(df_final_loan_1_Current['grade']).sum()
charge_off_sum = df_final_loan_1_Charged_off['funded_amnt'].groupby(df_final_loan_1_Charged_off['grade']).sum()



# Draw pie chart on % distribution of Grade
#Use the index of the grouped data for x-axis values
fully_paid = ax_1[2][0].pie(fully_paid_sum.values, labels=fully_paid_sum.index,autopct='%1.1f%%',startangle=90,textprops={'fontsize': 6},pctdistance=0.8)
current = ax_1[2][1].pie(current_sum.values, labels=current_sum.index,autopct='%1.1f%%',startangle=90,textprops={'fontsize': 6},pctdistance=0.8)
charge_off = ax_1[2][2].pie(charge_off_sum.values, labels=charge_off_sum.index,autopct='%1.1f%%',startangle=90,textprops={'fontsize': 6},pctdistance=0.8)


#Set Title
ax_1[2][0].title.set_text('Fully_Paid_Grade')
ax_1[2][1].title.set_text('Current_Grade')
ax_1[2][2].title.set_text('Charged_Off_Grade')

# Calculate the sum of 'funded_amnt' for each 'emp_length'
fully_paid_sum = df_final_loan_1_Fully_Paid['funded_amnt'].groupby(df_final_loan_1_Fully_Paid['emp_length']).sum()
current_sum= df_final_loan_1_Current['funded_amnt'].groupby(df_final_loan_1_Current['emp_length']).sum()
charge_off_sum = df_final_loan_1_Charged_off['funded_amnt'].groupby(df_final_loan_1_Charged_off['emp_length']).sum()

# Draw pie chart on % distribution of emp_length
#Use the index of the grouped data for x-axis values

fully_paid = ax_1[3][0].pie(fully_paid_sum.values, labels=fully_paid_sum.index,autopct='%1.1f%%',startangle=90,textprops={'fontsize': 6},pctdistance=0.8)
current = ax_1[3][1].pie(current_sum.values, labels=current_sum.index,autopct='%1.1f%%',startangle=90,textprops={'fontsize': 6},pctdistance=0.8)
charge_off = ax_1[3][2].pie(charge_off_sum.values, labels=charge_off_sum.index,autopct='%1.1f%%',startangle=90,textprops={'fontsize': 6},pctdistance=0.8)


#Set Title
ax_1[3][0].title.set_text('Fully_Paid_emp_length')
ax_1[3][1].title.set_text('Current_emp_length')
ax_1[3][2].title.set_text('Charged_emp_length')


# Calculate the sum of 'funded_amnt' for the different Purpose
fully_paid_sum = df_final_loan_1_Fully_Paid['funded_amnt'].groupby(df_final_loan_1_Fully_Paid['purpose']).sum()
current_sum= df_final_loan_1_Current['funded_amnt'].groupby(df_final_loan_1_Current['purpose']).sum()
charge_off_sum = df_final_loan_1_Charged_off['funded_amnt'].groupby(df_final_loan_1_Charged_off['purpose']).sum()

# Draw pie chart on % distribution of purpose
#Use the index of the grouped data for x-axis values

fully_paid = ax_1[4][0].pie(fully_paid_sum.values, labels=fully_paid_sum.index,autopct='%1.1f%%',startangle=90,textprops={'fontsize': 6},pctdistance=0.8)
current = ax_1[4][1].pie(current_sum.values, labels=current_sum.index,autopct='%1.1f%%',startangle=90,textprops={'fontsize': 6},pctdistance=0.8)
charge_off = ax_1[4][2].pie(charge_off_sum.values, labels=charge_off_sum.index,autopct='%1.1f%%',startangle=90,textprops={'fontsize': 6},pctdistance=0.8)


#Set Title
ax_1[4][0].title.set_text('Fully_Paid_purpose')
ax_1[4][1].title.set_text('Current_purpose')
ax_1[4][2].title.set_text('Charged_purpose')


# Drop row contains debt_consolidation from fully_paid_sum dataframe
fully_paid_sum = fully_paid_sum.drop('debt_consolidation')
current_sum = current_sum.drop('debt_consolidation')
charge_off_sum = charge_off_sum.drop('debt_consolidation')

# Draw pie chart on % distribution of purpose
#Use the index of the grouped data for x-axis values

fully_paid = ax_1[5][0].pie(fully_paid_sum.values, labels=fully_paid_sum.index,autopct='%1.1f%%',startangle=90,textprops={'fontsize': 6},pctdistance=0.8)
current = ax_1[5][1].pie(current_sum.values, labels=current_sum.index,autopct='%1.1f%%',startangle=90,textprops={'fontsize': 6},pctdistance=0.8)
charge_off = ax_1[5][2].pie(charge_off_sum.values, labels=charge_off_sum.index,autopct='%1.1f%%',startangle=90,textprops={'fontsize': 6},pctdistance=0.8)


#Set Title
ax_1[5][0].title.set_text('Fully_Paid_purpose_Without_Debt')
ax_1[5][1].title.set_text('Current_purpose_Without_Debt')
ax_1[5][2].title.set_text('Charged_purpose_Without_Debt')

# Creating pie distribution for loan amount bin

fully_paid_bin = df_final_loan_1_Fully_Paid['loan_amnt_bins'].value_counts()
current_bin = df_final_loan_1_Current['loan_amnt_bins'].value_counts()
charge_off_bin = df_final_loan_1_Charged_off['loan_amnt_bins'].value_counts()

fully_paid = ax_1[6][0].pie(fully_paid_bin.values, labels=fully_paid_bin.index,autopct='%1.1f%%',startangle=90,textprops={'fontsize': 6},pctdistance=0.8)
current = ax_1[6][1].pie(current_bin.values, labels=current_bin.index,autopct='%1.1f%%',startangle=90,textprops={'fontsize': 6},pctdistance=0.8)
charge_off = ax_1[6][2].pie(charge_off_bin.values, labels=charge_off_bin.index,autopct='%1.1f%%',startangle=90,textprops={'fontsize': 6},pctdistance=0.8)


#Set Title
ax_1[6][0].title.set_text('Fully_Paid_bins')
ax_1[6][1].title.set_text('Current_bins')
ax_1[6][2].title.set_text('Charged_bins')


#Show
plt.show()

# %%
#Univariate Analysis
# Create Histogram using DTI , Interest rate and Installment

fig_2, ax_2 = plt.subplots (ncols=3, nrows=4, figsize=(15,20), sharex= False ,sharey=False)

fully_paid_dti = sns.histplot(df_final_loan_1_Fully_Paid['dti'],bins=30,color='green', ax=ax_2[0][0])
current_dti = sns.histplot(df_final_loan_1_Current['dti'],bins=30,color='blue', ax=ax_2[0][1])
charge_off_dti = sns.histplot(df_final_loan_1_Charged_off['dti'],bins=30,color='red', ax=ax_2[0][2])


ax_2[0][0].title.set_text('Fully Paid_DTI')
ax_2[0][1].title.set_text('Current_DTI')
ax_2[0][2].title.set_text('Charged Off_DTI')

# Plotting Histogram for Interest Rate

fully_paid_int_rate = sns.histplot(df_final_loan_1_Fully_Paid['int_rate_percent'],bins=40,color='green', ax=ax_2[1][0])
current_int_rate = sns.histplot(df_final_loan_1_Current['int_rate_percent'],bins=40,color='blue', ax=ax_2[1][1])
charge_off_int_rate = sns.histplot(df_final_loan_1_Charged_off['int_rate_percent'],bins=40,color='red', ax=ax_2[1][2])


ax_2[1][0].title.set_text('Fully Paid_INT_RATE')
ax_2[1][1].title.set_text('Current_INT_RATE')
ax_2[1][2].title.set_text('Charged Off_INT_RATE')

# Plotting Histogram for Installment

fully_paid_installment = sns.histplot(df_final_loan_1_Fully_Paid['installment'],bins=30,color='green', ax=ax_2[2][0])
current_installment = sns.histplot(df_final_loan_1_Current['installment'],bins=30,color='blue', ax=ax_2[2][1])
charge_off_installment = sns.histplot(df_final_loan_1_Charged_off['installment'],bins=30,color='red', ax=ax_2[2][2])


ax_2[2][0].title.set_text('Fully Paid_installment')
ax_2[2][1].title.set_text('Current_installment')
ax_2[2][2].title.set_text('Charged Off_installment')


# Plotting Histogram for Total number of open accounts
fully_paid_total_acc = sns.histplot(df_final_loan_1_Fully_Paid['total_acc'],bins=30,color='green', ax=ax_2[3][0])
current_total_acc = sns.histplot(df_final_loan_1_Current['total_acc'],bins=30,color='blue', ax=ax_2[3][1])
charge_off_total_acc = sns.histplot(df_final_loan_1_Charged_off['total_acc'],bins=30,color='red', ax=ax_2[3][2])


ax_2[3][0].title.set_text('Fully Paid_total_acc')
ax_2[3][1].title.set_text('Current_total_acc')
ax_2[3][2].title.set_text('Charged Off_total_acc')




#Show
plt.show()

# %%
#Bi and Multi ivariate Analysis

fig_3, ax_3 = plt.subplots (ncols=3, nrows=1, figsize=(20,7), sharex= False ,sharey=False)

sns.heatmap(df_final_loan_1_Fully_Paid[['dti','int_rate_percent','installment','total_acc','annual_inc','revol_util_percent','revol_bal']].corr(),ax=ax_3[0])
sns.heatmap(df_final_loan_1_Current[['dti','int_rate_percent','installment','total_acc','annual_inc','revol_util_percent','revol_bal']].corr(),ax=ax_3[1])
sns.heatmap(df_final_loan_1_Charged_off[['dti','int_rate_percent','installment','total_acc','annual_inc','revol_util_percent','revol_bal']].corr(),ax=ax_3[2])

# Rotate x-axis labels for each axes in the array
for ax in ax_3:
    ax.tick_params(axis='x', rotation=60)
    ax.tick_params(axis='y', rotation=45)

ax_3[0].title.set_text('Fully Paid')
ax_3[1].title.set_text('Current')
ax_3[2].title.set_text('Charged Off')


plt.show()
